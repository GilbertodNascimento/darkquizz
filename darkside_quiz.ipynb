# %%
def mostrar_resultado(respostas):
    perfis = {
        "DarkLove": {
            "nome": "Dark Love",
            "descricao": "Você é um romântico sombrio, que busca a beleza nas trevas. Seus livros favoritos misturam amor e horror.",
            "livros": [
                {"titulo": "O Morro dos Ventos Uivantes", "sinopse": "Amor trágico e gótico."},
                {"titulo": "A Casa dos Espíritos", "sinopse": "Romance com realismo mágico e toques sobrenaturais."}
            ]
        },
        "Caveirinha das Trevas": {
            "nome": "Caveirinha das Trevas",
            "descricao": "Você gosta do terror psicológico e do inexplicável. Sua mente é uma casa assombrada.",
            "livros": [
                {"titulo": "O Iluminado", "sinopse": "Isolamento, loucura e fantasmas no Hotel Overlook."},
                {"titulo": "O Demonologista", "sinopse": "Demonologia e tensão psicológica intensa."}
            ]
        },
        "Visionário Macabro": {
            "nome": "Visionário Macabro",
            "descricao": "Você busca o desconhecido, gosta de ficção científica sombria e distopias com toques macabros.",
            "livros": [
                {"titulo": "1984", "sinopse": "Distopia clássica que explora a vigilância e a repressão."},
                {"titulo": "A Mão Esquerda da Escuridão", "sinopse": "Ficção científica com temas de identidade e política."}
            ]
        },
        "Explorador do Bizarro": {
            "nome": "Explorador do Bizarro",
            "descricao": "Você é fascinado pelo surreal e pelo estranho. Gosta de fantasia excêntrica e bizarrices.",
            "livros": [
                {"titulo": "Alice no País das Maravilhas", "sinopse": "Uma viagem absurda por um mundo de fantasia e lógica distorcida."},
                {"titulo": "O Hobbit", "sinopse": "Uma jornada épica com criaturas bizarras e mundos inexplorados."}
            ]
        },
        "Arqueólogo do Medo": {
            "nome": "Arqueólogo do Medo",
            "descricao": "Você gosta do terror clássico, histórias que exploram o medo primal e mistérios antigos.",
            "livros": [
                {"titulo": "Drácula", "sinopse": "O clássico do terror que mistura medo e paixão sobrenatural."},
                {"titulo": "Frankenstein", "sinopse": "O conto do cientista obcecado e da criação monstruosa."}
            ]
        },
        "Sombrio Filosófico": {
            "nome": "Sombrio Filosófico",
            "descricao": "Você busca reflexões profundas sobre a vida e a morte, onde a filosofia e o existencialismo se encontram com a escuridão.",
            "livros": [
                {"titulo": "O Estranho", "sinopse": "Explora o absurdo da vida e a alienação do ser."},
                {"titulo": "A Náusea", "sinopse": "Filosofia existencialista com um olhar sombrio sobre a vida cotidiana."}
            ]
        }
    }

    mapa_respostas = {
        'a': "DarkLove",
        'b': "Caveirinha das Trevas",
        'c': "Visionário Macabro",
        'd': "Explorador do Bizarro",
        'e': "Arqueólogo do Medo",
        'f': "Sombrio Filosófico"
    }

    contagem = {}
    for r in respostas:
        perfil = mapa_respostas[r]
        contagem[perfil] = contagem.get(perfil, 0) + 1

    perfil_mais_frequente = max(contagem, key=contagem.get)
    perfil = perfis[perfil_mais_frequente]

    print(f"\n🕯️ Seu perfil é: {perfil['nome']}")
    print(f"\n🖤 {perfil['descricao']}")
    print("\n📚 Indicações de leitura:")
    for livro in perfil["livros"]:
        print(f"- {livro['titulo']}: {livro['sinopse']}")


def quiz():
    print("📖 Que tipo de leitor DarkSide você é?\n")

    respostas = []

    perguntas = [
        ("1. Qual é o seu ambiente ideal para ler?", [
            "a) Um cemitério sob a luz da lua (DarkLove)",
            "b) Um sótão empoeirado (Caveirinha das Trevas)",
            "c) Uma biblioteca antiga e empoeirada (Visionário Macabro)",
            "d) Um parque de diversões abandonado (Explorador do Bizarro)",
            "e) Um quarto escuro e silencioso (Arqueólogo do Medo)",
            "f) Um café com luz baixa e música clássica (Sombrio Filosófico)"
        ]),
        ("2. Qual desses gêneros você prefere?", [
            "a) Romance gótico (DarkLove)",
            "b) Terror psicológico (Caveirinha das Trevas)",
            "c) Ficção científica sombria (Visionário Macabro)",
            "d) Fantasia bizarra (Explorador do Bizarro)",
            "e) Horror clássico (Arqueólogo do Medo)",
            "f) Filosofia sombria (Sombrio Filosófico)"
        ]),
        ("3. Se você pudesse viver em um livro, qual escolheria?", [
            "a) A Casa dos Espíritos (DarkLove)",
            "b) O Iluminado (Caveirinha das Trevas)",
            "c) 1984 (Visionário Macabro)",
            "d) Alice no País das Maravilhas (Explorador do Bizarro)",
            "e) Drácula (Arqueólogo do Medo)",
            "f) O Estranho (Sombrio Filosófico)"
        ]),
        ("4. Qual é o seu maior medo?", [
            "a) Perder a pessoa amada (DarkLove)",
            "b) A solidão e a insanidade (Caveirinha das Trevas)",
            "c) O controle e a opressão (Visionário Macabro)",
            "d) A falta de lógica no mundo (Explorador do Bizarro)",
            "e) O desconhecido e o incompreensível (Arqueólogo do Medo)",
            "f) A dúvida existencial (Sombrio Filosófico)"
        ])
    ]

    for pergunta, opcoes in perguntas:
        print(f"\n{pergunta}")
        for opcao in opcoes:
            print(opcao)
        resposta = input("Escolha a opção (a-f): ").strip().lower()

        while resposta not in ['a', 'b', 'c', 'd', 'e', 'f']:
            print("⚠️ Resposta inválida. Por favor, escolha uma opção válida (a-f).")
            resposta = input("Escolha a opção (a-f): ").strip().lower()

        respostas.append(resposta)

    mostrar_resultado(respostas)


# Iniciar o quiz
quiz()
# Out:
# 📖 Que tipo de leitor DarkSide você é?
#
#
# 1. Qual é o seu ambiente ideal para ler?
# a) Um cemitério sob a luz da lua (DarkLove)
# b) Um sótão empoeirado (Caveirinha das Trevas)
# c) Uma biblioteca antiga e empoeirada (Visionário Macabro)
# d) Um parque de diversões abandonado (Explorador do Bizarro)
# e) Um quarto escuro e silencioso (Arqueólogo do Medo)
# f) Um café com luz baixa e música clássica (Sombrio Filosófico)
# Escolha a opção (a-f): m
# ⚠️ Resposta inválida. Por favor, escolha uma opção válida (a-f).
